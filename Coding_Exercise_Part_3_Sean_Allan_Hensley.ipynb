# %% [markdown]
# <a href="https://colab.research.google.com/github/SeanHensley1/AAI2025/blob/2026fall/Coding_Exercise_Part_3_Sean_Allan_Hensley.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Original Summary Prompt:
# Summarize the results of the Python discount calculator exercise in one paragraph. Explain what the program does, mention the main input checks it performs, and briefly describe how the code was tested. Keep the summary clear and easy to understand for a college student, and do not add any information that was not part of the exercise.
#
# Self-Reflection Prompt:
# Review the summary you just wrote and critique it. Check whether it is accurate, clear, focused, and easy to understand. Make sure it clearly explains the purpose of the program, the input validation, the testing process, and the improvement that was made after finding the Boolean value issue. Also check whether the summary is between 90 and 110 words and is written as one paragraph. Explain what the summary does well and what should be improved before rewriting it.
#
# Revision Prompt:
# Now rewrite the summary using the feedback from your critique. Keep it between 90 and 110 words and use one paragraph. Make sure the revised version clearly explains what the program does, the input validation rules, how the code was tested, and how the program was improved after the Boolean value issue was found. Keep the wording clear and appropriate for a college student, and do not add any information that was not already included in the original exercise.
