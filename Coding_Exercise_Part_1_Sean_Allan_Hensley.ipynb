# %% [markdown]
# <a href="https://colab.research.google.com/github/SeanHensley1/AAI2025/blob/2026fall/Coding_Exercise_Part_1_Sean_Allan_Hensley.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Prompt 1:**
# Act as a customer support assistant. Read the customer’s message and figure out what type of problem they are having. Classify the issue as shipping/delivery, billing, refund, product problem, account problem, or other. Also decide if the issue is low, medium, or high urgency and briefly explain why. Keep the response simple and professional and do not make up any information that the customer did not give you. The customer says, “Hi, I ordered a pair of headphones five days ago, but the tracking has not updated and I still have not received them. Can you tell me what is going on?”
#
# **Prompt 2:**
# Using the customer’s original message and the classification from the first prompt, determine what information is still missing before the problem can be handled. Do not ask for information that the customer already gave. Ask for no more than two things that would help solve the problem, and then write a short question that could be sent back to the customer. The first prompt classified the issue as a shipping or delivery problem with medium urgency because the package has not arrived and the tracking has not updated.
#
# **Prompt 3:**
# Now use the original customer message, the classification from the first step, the missing information from the second step, and the customer’s follow-up to recommend what should happen next. The customer says that their order number is A10245 and the tracking page has shown “label created” for four days. Give a short and professional response to the customer, recommend the next action, and decide whether the issue should be passed to a human customer service employee. Do not promise a refund or replacement and do not make up any company policies.
